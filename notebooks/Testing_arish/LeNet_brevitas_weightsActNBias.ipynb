# %%
# https://xilinx.github.io/brevitas/getting_started.html

from torch.nn import Module
import torch.nn.functional as F

import brevitas.nn as qnn
from brevitas.quant import Int32Bias

import os
import onnx
import torch
import numpy as np
from torch.utils.data import TensorDataset
from torch.utils.data import DataLoader, Dataset
from brevitas.nn import QuantLinear, QuantReLU
import torch.nn as nn
from sklearn.metrics import accuracy_score
from tqdm import tqdm, trange
import ipynbname


class QuantWeightActBiasLeNet(Module):
    def __init__(self):
        super(QuantWeightActBiasLeNet, self).__init__()
        self.quant_inp = qnn.QuantIdentity(bit_width=4, return_quant_tensor=True)
        self.conv1 = qnn.QuantConv2d(3, 6, 5, bias=True, weight_bit_width=4, bias_quant=Int32Bias)
        self.relu1 = qnn.QuantReLU(bit_width=4, return_quant_tensor=True)
        self.conv2 = qnn.QuantConv2d(6, 16, 5, bias=True, weight_bit_width=4, bias_quant=Int32Bias)
        self.relu2 = qnn.QuantReLU(bit_width=4, return_quant_tensor=True)
        self.fc1   = qnn.QuantLinear(16*5*5, 120, bias=True, weight_bit_width=4, bias_quant=Int32Bias)
        self.relu3 = qnn.QuantReLU(bit_width=4, return_quant_tensor=True)
        self.fc2   = qnn.QuantLinear(120, 84, bias=True, weight_bit_width=4, bias_quant=Int32Bias)
        self.relu4 = qnn.QuantReLU(bit_width=4, return_quant_tensor=True)
        self.fc3   = qnn.QuantLinear(84, 10, bias=True, weight_bit_width=4, bias_quant=Int32Bias)

    def forward(self, x):
        out = self.quant_inp(x)
        out = self.relu1(self.conv1(out))
        out = F.max_pool2d(out, 2)
        out = self.relu2(self.conv2(out))
        out = F.max_pool2d(out, 2)
        out = out.reshape(out.shape[0], -1)
        out = self.relu3(self.fc1(out))
        out = self.relu4(self.fc2(out))
        out = self.fc3(out)
        return out

quant_weight_act_bias_lenet = QuantWeightActBiasLeNet()

# ... training ...

# %% [markdown]
# ####  Convert to ONNX model

# %%
from brevitas.export import export_onnx_qcdq
import torch

# Weight-activation-bias model
export_onnx_qcdq(quant_weight_act_bias_lenet, torch.randn(1, 3, 32, 32), export_path='./4b_weight_act_bias_lenet.onnx')
# Out:
# /home/inets/arish/finn/deps/brevitas/src/brevitas/export/onnx/standard/manager.py:26: UserWarning: ONNX opset version set to 13, override with opset_version=
#   warnings.warn(f"ONNX opset version set to {DEFAULT_OPSET}, override with {ka}=")
# ir_version: 7
# producer_name: "pytorch"
# producer_version: "1.13.1"
# graph {
#   node {
#     input: "x.1"
#     input: "/quant_inp/act_quant/export_handler/Constant_output_0"
#     input: "/quant_inp/act_quant/export_handler/Constant_1_output_0"
#     output: "/quant_inp/act_quant/export_handler/QuantizeLinear_output_0"
#     name: "/quant_inp/act_quant/export_handler/QuantizeLinear"
#     op_type: "QuantizeLinear"
#   }
#   node {
#     input: "/quant_inp/act_quant/export_handler/QuantizeLinear_output_0"
#     input: "/quant_inp/act_quant/export_handler/Constant_2_output_0"
#     input: "/quant_inp/act_quant/export_handler/Constant_3_output_0"
#     output: "/quant_inp/act_quant/export_handler/Clip_output_0"
#     name: "/quant_inp/act_quant/export_handler/Clip"
#     op_type: "Clip"
#   }
#   node {
#     input: "/quant_inp/act_quant/export_handler/Clip_output_0"
#     input: "/quant_inp/act_quant/export_handler/Constant_output_0"
#     input: "/quant_inp/act_quant/export_handler/Constant_1_output_0"
#     output: "/quant_inp/act_quant/export_handler/DequantizeLinear_output_0"
#     name: "/quant_inp/act_quant/export_handler/DequantizeLinear"
#     op_type: "DequantizeLinear"
#   }
#   node {
#     input: "/conv1/weight_quant/export_handler/Constant_1_output_0"
#     input: "/conv1/weight_quant/export_handler/Constant_2_output_0"
#     input: "/quant_inp/act_quant/export_handler/Constant_3_output_0"
#     output: "/conv1/weight_quant/export_handler/Clip_output_0"
#     name: "/conv1/weight_quant/export_handler/Clip"
#     op_type: "Clip"
#   }
#   node {
#     input: "/conv1/weight_quant/export_handler/Clip_output_0"
#     input: "/conv1/weight_quant/export_handler/Constant_output_0"
#     input: "/quant_inp/act_quant/export_handler/Constant_1_output_0"
#     output: "/conv1/weight_quant/export_handler/DequantizeLinear_output_0"
#     name: "/conv1/weight_quant/export_handler/DequantizeLinear"
#     op_type: "DequantizeLinear"
#   }
#   node {
#     input: "/conv1/bias_quant/export_handler/Constant_output_0"
#     input: "onnx::DequantizeLinear_23"
#     input: "onnx::DequantizeLinear_24"
#     output: "/conv1/bias_quant/export_handler/DequantizeLinear_output_0"
#     name: "/conv1/bias_quant/export_handler/DequantizeLinear"
#     op_type: "DequantizeLinear"
#   }
#   node {
#     input: "/quant_inp/act_quant/export_handler/DequantizeLinear_output_0"
#     input: "/conv1/weight_quant/export_handler/DequantizeLinear_output_0"
#     input: "/conv1/bias_quant/export_handler/DequantizeLinear_output_0"
#     output: "/conv1/Conv_output_0"
#     name: "/conv1/Conv"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 5
#       ints: 5
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "/conv1/Conv_output_0"
#     output: "/relu1/act_quant/activation_impl/Relu_output_0"
#     name: "/relu1/act_quant/activation_impl/Relu"
#     op_type: "Relu"
#   }
#   node {
#     input: "/relu1/act_quant/activation_impl/Relu_output_0"
#     input: "/relu1/act_quant/export_handler/Constant_output_0"
#     input: "/relu1/act_quant/export_handler/Constant_1_output_0"
#     output: "/relu1/act_quant/export_handler/QuantizeLinear_output_0"
#     name: "/relu1/act_quant/export_handler/QuantizeLinear"
#     op_type: "QuantizeLinear"
#   }
#   node {
#     input: "/relu1/act_quant/export_handler/QuantizeLinear_output_0"
#     input: "/relu1/act_quant/export_handler/Constant_1_output_0"
#     input: "/relu1/act_quant/export_handler/Constant_2_output_0"
#     output: "/relu1/act_quant/export_handler/Clip_output_0"
#     name: "/relu1/act_quant/export_handler/Clip"
#     op_type: "Clip"
#   }
#   node {
#     input: "/relu1/act_quant/export_handler/Clip_output_0"
#     input: "/relu1/act_quant/export_handler/Constant_output_0"
#     input: "/relu1/act_quant/export_handler/Constant_1_output_0"
#     output: "/relu1/act_quant/export_handler/DequantizeLinear_output_0"
#     name: "/relu1/act_quant/export_handler/DequantizeLinear"
#     op_type: "DequantizeLinear"
#   }
#   node {
#     input: "/relu1/act_quant/export_handler/DequantizeLinear_output_0"
#     output: "/MaxPool_output_0"
#     name: "/MaxPool"
#     op_type: "MaxPool"
#     attribute {
#       name: "ceil_mode"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 2
#       ints: 2
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 2
#       ints: 2
#       type: INTS
#     }
#   }
#   node {
#     input: "/conv2/weight_quant/export_handler/Constant_1_output_0"
#     input: "/conv1/weight_quant/export_handler/Constant_2_output_0"
#     input: "/quant_inp/act_quant/export_handler/Constant_3_output_0"
#     output: "/conv2/weight_quant/export_handler/Clip_output_0"
#     name: "/conv2/weight_quant/export_handler/Clip"
#     op_type: "Clip"
#   }
#   node {
#     input: "/conv2/weight_quant/export_handler/Clip_output_0"
#     input: "/conv2/weight_quant/export_handler/Constant_output_0"
#     input: "/quant_inp/act_quant/export_handler/Constant_1_output_0"
#     output: "/conv2/weight_quant/export_handler/DequantizeLinear_output_0"
#     name: "/conv2/weight_quant/export_handler/DequantizeLinear"
#     op_type: "DequantizeLinear"
#   }
#   node {
#     input: "/conv2/bias_quant/export_handler/Constant_output_0"
#     input: "onnx::DequantizeLinear_40"
#     input: "onnx::DequantizeLinear_24"
#     output: "/conv2/bias_quant/export_handler/DequantizeLinear_output_0"
#     name: "/conv2/bias_quant/export_handler/DequantizeLinear"
#     op_type: "DequantizeLinear"
#   }
#   node {
#     input: "/MaxPool_output_0"
#     input: "/conv2/weight_quant/export_handler/DequantizeLinear_output_0"
#     input: "/conv2/bias_quant/export_handler/DequantizeLinear_output_0"
#     output: "/conv2/Conv_output_0"
#     name: "/conv2/Conv"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 5
#       ints: 5
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "/conv2/Conv_output_0"
#     output: "/relu2/act_quant/activation_impl/Relu_output_0"
#     name: "/relu2/act_quant/activation_impl/Relu"
#     op_type: "Relu"
#   }
#   node {
#     input: "/relu2/act_quant/activation_impl/Relu_output_0"
#     input: "/relu1/act_quant/export_handler/Constant_output_0"
#     input: "/relu1/act_quant/export_handler/Constant_1_output_0"
#     output: "/relu2/act_quant/export_handler/QuantizeLinear_output_0"
#     name: "/relu2/act_quant/export_handler/QuantizeLinear"
#     op_type: "QuantizeLinear"
#   }
#   node {
#     input: "/relu2/act_quant/export_handler/QuantizeLinear_output_0"
#     input: "/relu1/act_quant/export_handler/Constant_1_output_0"
#     input: "/relu1/act_quant/export_handler/Constant_2_output_0"
#     output: "/relu2/act_quant/export_handler/Clip_output_0"
#     name: "/relu2/act_quant/export_handler/Clip"
#     op_type: "Clip"
#   }
#   node {
#     input: "/relu2/act_quant/export_handler/Clip_output_0"
#     input: "/relu1/act_quant/export_handler/Constant_output_0"
#     input: "/relu1/act_quant/export_handler/Constant_1_output_0"
#     output: "/relu2/act_quant/export_handler/DequantizeLinear_output_0"
#     name: "/relu2/act_quant/export_handler/DequantizeLinear"
#     op_type: "DequantizeLinear"
#   }
#   node {
#     input: "/relu2/act_quant/export_handler/DequantizeLinear_output_0"
#     output: "/MaxPool_1_output_0"
#     name: "/MaxPool_1"
#     op_type: "MaxPool"
#     attribute {
#       name: "ceil_mode"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 2
#       ints: 2
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 2
#       ints: 2
#       type: INTS
#     }
#   }
#   node {
#     input: "/MaxPool_1_output_0"
#     input: "/Constant_output_0"
#     output: "/Reshape_output_0"
#     name: "/Reshape"
#     op_type: "Reshape"
#   }
#   node {
#     input: "/fc1/weight_quant/export_handler/Constant_1_output_0"
#     input: "/conv1/weight_quant/export_handler/Constant_2_output_0"
#     input: "/quant_inp/act_quant/export_handler/Constant_3_output_0"
#     output: "/fc1/weight_quant/export_handler/Clip_output_0"
#     name: "/fc1/weight_quant/export_handler/Clip"
#     op_type: "Clip"
#   }
#   node {
#     input: "/fc1/weight_quant/export_handler/Clip_output_0"
#     input: "/fc1/weight_quant/export_handler/Constant_output_0"
#     input: "/quant_inp/act_quant/export_handler/Constant_1_output_0"
#     output: "/fc1/weight_quant/export_handler/DequantizeLinear_output_0"
#     name: "/fc1/weight_quant/export_handler/DequantizeLinear"
#     op_type: "DequantizeLinear"
#   }
#   node {
#     input: "/fc1/bias_quant/export_handler/Constant_output_0"
#     input: "onnx::DequantizeLinear_61"
#     input: "onnx::DequantizeLinear_24"
#     output: "/fc1/bias_quant/export_handler/DequantizeLinear_output_0"
#     name: "/fc1/bias_quant/export_handler/DequantizeLinear"
#     op_type: "DequantizeLinear"
#   }
#   node {
#     input: "/Reshape_output_0"
#     input: "/fc1/weight_quant/export_handler/DequantizeLinear_output_0"
#     input: "/fc1/bias_quant/export_handler/DequantizeLinear_output_0"
#     output: "/fc1/Gemm_output_0"
#     name: "/fc1/Gemm"
#     op_type: "Gemm"
#     attribute {
#       name: "alpha"
#       f: 1.0
#       type: FLOAT
#     }
#     attribute {
#       name: "beta"
#       f: 1.0
#       type: FLOAT
#     }
#     attribute {
#       name: "transB"
#       i: 1
#       type: INT
#     }
#   }
#   node {
#     input: "/fc1/Gemm_output_0"
#     output: "/relu3/act_quant/activation_impl/Relu_output_0"
#     name: "/relu3/act_quant/activation_impl/Relu"
#     op_type: "Relu"
#   }
#   node {
#     input: "/relu3/act_quant/activation_impl/Relu_output_0"
#     input: "/relu1/act_quant/export_handler/Constant_output_0"
#     input: "/relu1/act_quant/export_handler/Constant_1_output_0"
#     output: "/relu3/act_quant/export_handler/QuantizeLinear_output_0"
#     name: "/relu3/act_quant/export_handler/QuantizeLinear"
#     op_type: "QuantizeLinear"
#   }
#   node {
#     input: "/relu3/act_quant/export_handler/QuantizeLinear_output_0"
#     input: "/relu1/act_quant/export_handler/Constant_1_output_0"
#     input: "/relu1/act_quant/export_handler/Constant_2_output_0"
#     output: "/relu3/act_quant/export_handler/Clip_output_0"
#     name: "/relu3/act_quant/export_handler/Clip"
#     op_type: "Clip"
#   }
#   node {
#     input: "/relu3/act_quant/export_handler/Clip_output_0"
#     input: "/relu1/act_quant/export_handler/Constant_output_0"
#     input: "/relu1/act_quant/export_handler/Constant_1_output_0"
#     output: "/relu3/act_quant/export_handler/DequantizeLinear_output_0"
#     name: "/relu3/act_quant/export_handler/DequantizeLinear"
#     op_type: "DequantizeLinear"
#   }
#   node {
#     input: "/fc2/weight_quant/export_handler/Constant_1_output_0"
#     input: "/conv1/weight_quant/export_handler/Constant_2_output_0"
#     input: "/quant_inp/act_quant/export_handler/Constant_3_output_0"
#     output: "/fc2/weight_quant/export_handler/Clip_output_0"
#     name: "/fc2/weight_quant/export_handler/Clip"
#     op_type: "Clip"
#   }
#   node {
#     input: "/fc2/weight_quant/export_handler/Clip_output_0"
#     input: "/fc2/weight_quant/export_handler/Constant_output_0"
#     input: "/quant_inp/act_quant/export_handler/Constant_1_output_0"
#     output: "/fc2/weight_quant/export_handler/DequantizeLinear_output_0"
#     name: "/fc2/weight_quant/export_handler/DequantizeLinear"
#     op_type: "DequantizeLinear"
#   }
#   node {
#     input: "/fc2/bias_quant/export_handler/Constant_output_0"
#     input: "onnx::DequantizeLinear_73"
#     input: "onnx::DequantizeLinear_24"
#     output: "/fc2/bias_quant/export_handler/DequantizeLinear_output_0"
#     name: "/fc2/bias_quant/export_handler/DequantizeLinear"
#     op_type: "DequantizeLinear"
#   }
#   node {
#     input: "/relu3/act_quant/export_handler/DequantizeLinear_output_0"
#     input: "/fc2/weight_quant/export_handler/DequantizeLinear_output_0"
#     input: "/fc2/bias_quant/export_handler/DequantizeLinear_output_0"
#     output: "/fc2/Gemm_output_0"
#     name: "/fc2/Gemm"
#     op_type: "Gemm"
#     attribute {
#       name: "alpha"
#       f: 1.0
#       type: FLOAT
#     }
#     attribute {
#       name: "beta"
#       f: 1.0
#       type: FLOAT
#     }
#     attribute {
#       name: "transB"
#       i: 1
#       type: INT
#     }
#   }
#   node {
#     input: "/fc2/Gemm_output_0"
#     output: "/relu4/act_quant/activation_impl/Relu_output_0"
#     name: "/relu4/act_quant/activation_impl/Relu"
#     op_type: "Relu"
#   }
#   node {
#     input: "/relu4/act_quant/activation_impl/Relu_output_0"
#     input: "/relu1/act_quant/export_handler/Constant_output_0"
#     input: "/relu1/act_quant/export_handler/Constant_1_output_0"
#     output: "/relu4/act_quant/export_handler/QuantizeLinear_output_0"
#     name: "/relu4/act_quant/export_handler/QuantizeLinear"
#     op_type: "QuantizeLinear"
#   }
#   node {
#     input: "/relu4/act_quant/export_handler/QuantizeLinear_output_0"
#     input: "/relu1/act_quant/export_handler/Constant_1_output_0"
#     input: "/relu1/act_quant/export_handler/Constant_2_output_0"
#     output: "/relu4/act_quant/export_handler/Clip_output_0"
#     name: "/relu4/act_quant/export_handler/Clip"
#     op_type: "Clip"
#   }
#   node {
#     input: "/relu4/act_quant/export_handler/Clip_output_0"
#     input: "/relu1/act_quant/export_handler/Constant_output_0"
#     input: "/relu1/act_quant/export_handler/Constant_1_output_0"
#     output: "/relu4/act_quant/export_handler/DequantizeLinear_output_0"
#     name: "/relu4/act_quant/export_handler/DequantizeLinear"
#     op_type: "DequantizeLinear"
#   }
#   node {
#     input: "/fc3/weight_quant/export_handler/Constant_1_output_0"
#     input: "/conv1/weight_quant/export_handler/Constant_2_output_0"
#     input: "/quant_inp/act_quant/export_handler/Constant_3_output_0"
#     output: "/fc3/weight_quant/export_handler/Clip_output_0"
#     name: "/fc3/weight_quant/export_handler/Clip"
#     op_type: "Clip"
#   }
#   node {
#     input: "/fc3/weight_quant/export_handler/Clip_output_0"
#     input: "/fc3/weight_quant/export_handler/Constant_output_0"
#     input: "/quant_inp/act_quant/export_handler/Constant_1_output_0"
#     output: "/fc3/weight_quant/export_handler/DequantizeLinear_output_0"
#     name: "/fc3/weight_quant/export_handler/DequantizeLinear"
#     op_type: "DequantizeLinear"
#   }
#   node {
#     input: "/fc3/bias_quant/export_handler/Constant_output_0"
#     input: "onnx::DequantizeLinear_85"
#     input: "onnx::DequantizeLinear_24"
#     output: "/fc3/bias_quant/export_handler/DequantizeLinear_output_0"
#     name: "/fc3/bias_quant/export_handler/DequantizeLinear"
#     op_type: "DequantizeLinear"
#   }
#   node {
#     input: "/relu4/act_quant/export_handler/DequantizeLinear_output_0"
#     input: "/fc3/weight_quant/export_handler/DequantizeLinear_output_0"
#     input: "/fc3/bias_quant/export_handler/DequantizeLinear_output_0"
#     output: "88"
#     name: "/fc3/Gemm"
#     op_type: "Gemm"
#     attribute {
#       name: "alpha"
#       f: 1.0
#       type: FLOAT
#     }
#     attribute {
#       name: "beta"
#       f: 1.0
#       type: FLOAT
#     }
#     attribute {
#       name: "transB"
#       i: 1
#       type: INT
#     }
#   }
#   name: "torch_jit"
#   initializer {
#     data_type: 1
#     name: "/quant_inp/act_quant/export_handler/Constant_output_0"
#     raw_data: "\000\000\000>"
#   }
#   initializer {
#     data_type: 3
#     name: "/quant_inp/act_quant/export_handler/Constant_1_output_0"
#     raw_data: "\000"
#   }
#   initializer {
#     data_type: 3
#     name: "/quant_inp/act_quant/export_handler/Constant_2_output_0"
#     raw_data: "\370"
#   }
#   initializer {
#     data_type: 3
#     name: "/quant_inp/act_quant/export_handler/Constant_3_output_0"
#     raw_data: "\007"
#   }
#   initializer {
#     data_type: 1
#     name: "/conv1/weight_quant/export_handler/Constant_output_0"
#     raw_data: "\021\377\206<"
#   }
#   initializer {
